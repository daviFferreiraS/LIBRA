# %%
import gensim
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
import nltk
nltk.download('all') # para evitar futuras dependências
from nltk.corpus import stopwords

# %% [markdown]
# Lendo o dataset e fazendo o pré processamento

# %%
df_text = pd.read_csv('dataset.csv', sep=";")

# %%
df_text.head()
# Out:
#                                               phrase  emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness

# %%
english_stopwords = stopwords.words("english")
# no dataset tem im ao invés de I'm, então fez-se esse tipo de exclusão também.
more_words = ['im', 'ive', 'youve', 'youll', 'youd', 'wasnt', 'shouldve', 'hes', 'shes', 'dont', 'doesnt', 'didnt', 'couldnt',
'wouldnt', 'werent', 'hasnt', 'arent','wont']
for word in more_words:
  english_stopwords.append(word)

# %%
# faz a tokenização usando como separador o espaço em branco
whitespace_tokenizer = nltk.tokenize.WhitespaceTokenizer()

# %% [markdown]
# Remoção das stopwords

# %%
# retirando as palavras que estão contidas na lista de stopwords
df_text_nostop = df_text['phrase'].apply(lambda x: ' '.join(x for x in x.split() if x not in english_stopwords))

# %% [markdown]
# Lemmatização

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    lemma_words = [lemmatizer.lemmatize(w) for w in whitespace_tokenizer.tokenize(text)]
    return ' '.join(lemma_words)
df_text_nostop = df_text_nostop.apply(lemmatize_text)
df_text_nostop.head()
# Out:
# 0                feeling rather rotten ambitious right
# 1                            updating blog feel shitty
# 2      never make separate ever want feel like ashamed
# 3    left bouquet red yellow tulip arm feeling slig...
# 4                              feeling little vain one
# Name: phrase, dtype: object

# %%
def read_file(df):
  for i, phrase in enumerate(df):
    if i % 1000 == 0:
      print("li {0} frases".format(i))

    yield gensim.utils.simple_preprocess(phrase) # faz a tokenização (talvez desnecessário)

# %% [markdown]
# Pré processamento feito

# %%
documents = list(read_file(df_text_nostop))
print(documents)
# Out:
# li 0 frases
# li 1000 frases
# li 2000 frases
# li 3000 frases
# li 4000 frases
# li 5000 frases
# li 6000 frases
# li 7000 frases
# li 8000 frases
# li 9000 frases
# li 10000 frases
# li 11000 frases
# li 12000 frases
# li 13000 frases
# li 14000 frases
# li 15000 frases
# li 16000 frases
# li 17000 frases
# li 18000 frases
# li 19000 frases
# [['feeling', 'rather', 'rotten', 'ambitious', 'right'], ['updating', 'blog', 'feel', 'shitty'], ['never', 'make', 'separate', 'ever', 'want', 'feel', 'like', 'ashamed'], ['left', 'bouquet', 'red', 'yellow', 'tulip', 'arm', 'feeling', 'slightly', 'optimistic', 'arrived'], ['feeling', 'little', 'vain', 'one'], ['cant', 'walk', 'shop', 'anywhere', 'feel', 'uncomfortable'], ['felt', 'anger', 'end', 'telephone', 'call'], ['explain', 'clung', 'relationship', 'boy', 'many', 'way', 'immature', 'uncommitted', 'despite', 'excitement', 'feeling', 'getting', 'accepted', 'master', 'program', 'university', 'virginia'], ['like', 'breathless', 'feeling', 'reader', 'eager', 'see', 'happen', 'next'], ['jest', 'feel', 'grumpy', 'tired', 'pre', 'menstrual', 'probably', 'week', 'fit', 'walrus', 'vacation', 'summer'], ['feel', 'particularly', 'agitated'], ['feel', 'beautifully', 'emotional', 'knowing', 'woman', 'knew', 'handful', 'holding', 'baba', 'journey'], ['pay', 'attention', 'deepens', 'feeling', 'invaded', 'helpless'], ['feel', 'extremely', 'comfortable', 'group', 'people', 'even', 'need', 'hide'], ['find', 'odd', 'position', 'feeling', 'supportive'], ['feeling', 'heartbroken', 'sure', 'katniss'], ['feel', 'little', 'mellow', 'today'], ['feel', 'like', 'role', 'would', 'tear', 'sail', 'pessimism', 'discontent'], ['feel', 'bcoz', 'fight', 'get', 'mad', 'wanna', 'make', 'publicity', 'let', 'world', 'know', 'fight'], ['feel', 'like', 'red', 'purple', 'rich', 'kind', 'perfect'], ['sure', 'feeling', 'loss', 'ever', 'go', 'away', 'may', 'dull', 'sweet', 'feeling', 'nostalgia', 'shared', 'life', 'dad', 'luck', 'dad', 'year'], ['feel', 'like', 'gotten', 'know', 'many', 'comment', 'email', 'appreciative', 'glad', 'part', 'little', 'space'], ['survey', 'post', 'last', 'year', 'feel', 'pleased', 'vague', 'snippet', 'feel', 'little', 'bit', 'capture', 'like', 'someone', 'like', 'dublin', 'st', 'century'], ['also', 'tell', 'hope', 'anyone', 'still', 'feeling', 'stigmatized', 'ashamed', 'mental', 'health', 'issue', 'let', 'go', 'stigma', 'let', 'go', 'shame'], ['feel', 'guilty', 'like', 'going', 'able', 'cook'], ['hate', 'feel', 'fearful', 'absolutely', 'reason'], ['feeling', 'outraged', 'show', 'everywhere'], ['stole', 'book', 'one', 'time', 'favorite', 'author', 'feel', 'like', 'rotten', 'person'], ['feel', 'insecure', 'sometimes'], ['highly', 'recommend', 'visiting', 'wednesday', 'youre', 'able', 'le', 'crowded', 'get', 'ask', 'farmer', 'question', 'without', 'feeling', 'rude', 'holding', 'line'], ['missing', 'feeling', 'restless', 'home', 'thinking'], ['posted', 'facebook', 'page', 'earlier', 'week', 'feeling', 'little', 'grumpy', 'sort', 'past', 'day'], ['start', 'feel', 'emotional'], ['feel', 'cold', 'href', 'http', 'irish'], ['feel', 'like', 'defective', 'something', 'baby', 'fever'], ['feel', 'virtuous', 'eat', 'veggie', 'dipped', 'hummus'], ['feel', 'honoured', 'included', 'magzine', 'prioritises', 'health', 'clean', 'living', 'highly', 'curious', 'read', 'magazine', 'concerned', 'health', 'clean', 'lifestyle', 'green', 'parent'], ['spent', 'last', 'two', 'week', 'school', 'feeling', 'miserable'], ['feeling', 'peaceful', 'wedding'], ['talking', 'coach', 'claudia', 'barcomb', 'coach', 'ali', 'boe', 'long', 'time', 'made', 'feel', 'welcomed', 'union'], ['feel', 'completely', 'hated', 'thing', 'exercise', 'democratic', 'right', 'speak', 'mind', 'ever', 'way', 'possible', 'try', 'enact', 'change'], ['feel', 'humiliated', 'embarrassed', 'foolish', 'remember', 'others', 'felt', 'way', 'kind', 'thing', 'kind', 'helpful', 'accepting'], ['feel', 'reassured', 'dealing', 'diet', 'right', 'way', 'good'], ['feel', 'agree', 'even', 'though', 'imagine', 'rather', 'unpleasant', 'possible', 'case'], ['happy', 'mood', 'today', 'feel', 'almost', 'delighted', 'havent', 'done', 'anything', 'different', 'today', 'normally', 'wonderful'], ['feeling', 'really', 'place', 'irritated'], ['also', 'know', 'feel', 'nothing', 'friendly', 'affection'], ['feel', 'like', 'rather' ...

# %% [markdown]
# Divisão do dataset tratado

# %%
X_train, X_test, y_train, y_test = train_test_split(documents, df_text["emotion"], test_size=0.3)

# %% [markdown]
# # Word2Vec

# %% [markdown]
# Treinamento do word2vec e vetorização das palavras

# %%
model_w2v = gensim.models.Word2Vec(X_train, vector_size=200, window= 10, workers= 6)

# %%
model_w2v.train(X_train, total_examples = len(X_train), epochs= 20)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (1839163, 2526760)

# %% [markdown]
# Observação: A taxa de aprendizado, quando se treina o word2vec, tava dando alta a cada época (o que indica que tá tendo problema de aprendizado do word2vec no dataset) (possível sugestão: trocar o dataset?)

# %%
w2v_words = list(model_w2v.wv.index_to_key) # pegando todas as palavras dentro do Word2Vec

# %%
w2v_words

# %% [markdown]
# Vetorizando

# %%
def vectorize(sentence):
  words_vecs = [model_w2v.wv[word] for word in sentence if word in w2v_words]
  if len(words_vecs) == 0:
    return np.zeros(200)
  words_vecs = np.array(words_vecs, dtype= float)
  return words_vecs.mean(axis=0)

# %%
X_train = np.array([vectorize(sentence) for sentence in X_train])
X_test = np.array([vectorize(sentence) for sentence in X_test])

# %% [markdown]
# Usando classificadores

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.multiclass import OneVsRestClassifier

# %% [markdown]
# Como o word2vec gera embeddings com números negativos, é preferivel fazer uma normalização com o MinMaxScaler

# %%
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
log_regression = LogisticRegression()
ovr = OneVsRestClassifier(log_regression)
ovr.fit(X_train, y_train)
y_pred = ovr.predict(X_test)

# %%
# cnb = ComplementNB()

# # Como o word2vec tá retornando valores negativos, fiz um min max pra arrumar a
# # escala pro classificador.
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.fit_transform(X_test)
# cnb.fit(X_train, y_train)
# y_pred = cnb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.41683333333333333
# Precision: 0.5033670124366019
# Recall: 0.41683333333333333
# F1-score: 0.37713140087266184

# %% [markdown]
# Performance mto ruim
#
# Possiveis melhorias:
# Usar outros classificadores, Logistic Regression e SVM (Usar o one-vs-rest ou one-vs-one para gerar mais classificadores)
# Talvez trocar o dataset

# %% [markdown]
# # Fast Text

# %%
X_train, X_test, y_train, y_test = train_test_split(documents, df_text["emotion"], test_size=0.3)

# %%
from gensim.models.fasttext import FastText

# %%
model_ft = FastText(X_train, vector_size = 150, window= 10, min_count = 2, workers= 4)
# Out:
# WARNING:gensim.models.keyedvectors:sorting after vectors have been allocated is expensive & error-prone

# %%
model_ft.train(X_train, total_examples = len(X_train), epochs= 20)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (2317756, 2887340)

# %% [markdown]
# Vetorização

# %%
ft_words = model_ft.wv.index_to_key # pegando todas as palavras dentro do FastText

# %%
ft_words

# %%
def vectorize(sentence):
  words_vecs = [model_ft.wv[word] for word in sentence if word in ft_words]
  if len(words_vecs) == 0:
    return np.zeros(150)
  words_vecs = np.array(words_vecs)
  return words_vecs.mean(axis=0)

# %%
X_train = np.array([vectorize(sentence) for sentence in X_train])
X_test = np.array([vectorize(sentence) for sentence in X_test])

# %% [markdown]
# Classificadores

# %%
# cnb = ComplementNB()

# # Como o FastText tbm tá retornando valores negativos, fiz um min max pra arrumar a
# # escala pro classificador.
# scaler = MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.fit_transform(X_test)
# cnb.fit(X_train, y_train)
# y_pred = cnb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', labels=np.unique(y_pred))
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.38975
# Precision: 0.33238201282076113
# Recall: 0.38975
# F1-score: 0.3286917622022275

# %% [markdown]
# Deu a mesma performance ruim
#
# Me pergunto se a vetorização está funcionando conforme o esperado (eu imagino que sim)
