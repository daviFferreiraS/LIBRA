# %%
from model_utils import sample_negative, get_batches
from word2vecs import Word2Vec_negative, Word2Vec, EarlyStopping
import pandas as pd
import itertools

# %%
df = pd.read_csv("dataset copy.csv", sep=";")

# %%
corpus = []

for phrase in df["phrase"]:
    corpus.append([word for word in phrase.split() if word != ' '])

# %%
from collections import Counter
import random, math

# %%
def subsample_frequent_words(corpus):
  filtered_corpus = []
  word_counts = dict(Counter(list(itertools.chain.from_iterable(corpus))))
  total = sum(list(word_counts.values()))
  # proportion of each word in corpus
  word_counts = {word: word_counts[word]/float(total) for word in word_counts}

  for text in corpus:
    filtered_corpus.append([])
    for word in text:
      if random.random() < (1+math.sqrt(word_counts[word]*1e3) * 1e-3 / word_counts[word]):
        filtered_corpus[-1].append(word)
  return filtered_corpus

# %%
corpus = subsample_frequent_words(corpus)
vocabulary = set(itertools.chain.from_iterable(corpus))

word_to_index = {word: index for (index, word) in enumerate(vocabulary)}
index_to_word = {index: word for (index, word) in enumerate(vocabulary)}

# %%
context = []
window = 4

# %%
for text in corpus:
  for i, word in enumerate(text):
    start = max(0, i-window)
    end = min(i+window, len(text))
    for j in range(start, end):
      if i != j:
        context.append((word,text[j]))

print(f"Tem-se um total de {len(context)} pares de palavras alvo e palavras contextuais")
# Out:
# Tem-se um total de 2018 pares de palavras alvo e palavras contextuais

# %%
import torch.optim as optim
import torch.nn as nn
import torch
import torch.autograd as autograd
import numpy as np

# %% [markdown]
# word2vec sem negativo

# %%
vocab_size = len(vocabulary)

w2v = Word2Vec(embedding_size= 200, vocab_size = vocab_size)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(w2v.parameters())
early_stopping = EarlyStopping()
context_tensor = []

# %%
for target, meaning in context:
  target_tensor = autograd.Variable(torch.LongTensor([word_to_index[target]]))
  meaning_tensor = autograd.Variable(torch.LongTensor([word_to_index[meaning]]))
  context_tensor.append((target_tensor, meaning_tensor))

# %%
while True:
  losses = []
  context_batches = get_batches(word_to_index, context= context, batch_size=1000)
  for i in range(len(context_batches)):
    w2v.zero_grad()
    target_tensor, meaning_tensor = context_batches[i]
    loss = w2v(target_tensor, meaning_tensor)
    loss.backward()
    optimizer.step()
    losses.append(loss.data)
  print("loss: ", np.mean(losses))
  early_stopping.update_loss(np.mean(losses))
  if early_stopping.stop_training():
    break
# Out:
# loss:  5.477333
# loss:  3.180909
# Ganho de custo: 489.66
# loss:  1.5443022
# Ganho de custo: 519.54
# loss:  0.6335019
# Ganho de custo: 536.17
# loss:  0.22166914
# Ganho de custo: 543.69
# loss:  0.06377351
# Ganho de custo: 316.09
# loss:  0.014253848
# Ganho de custo: 153.51
# loss:  0.004004623
# Ganho de custo: 62.72
# loss:  0.0005276215
# Ganho de custo: 21.93
# loss:  0.00021491354
# Ganho de custo: 6.04
# loss:  8.510561e-05
# Ganho de custo: 0.83

# %% [markdown]
# Word2vec com negativo

# %%
vocab_size = len(vocabulary)

w2v = Word2Vec_negative(embedding_size= 200, vocab_size = vocab_size)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(w2v.parameters())
early_stopping = EarlyStopping()
context_tensor = []

# %%
context = []
window = 4
negative_example = sample_negative(corpus, 1)

# %%
for text in corpus:
  for i, word in enumerate(text):
    
    start = max(0, i-window)
    end = min(i+window, len(text))
    print(text)
    for j in range(start, end):
      if i != j:
        aux = (word,text[j], next(negative_example)[0])
        print(aux[2], " --> ", aux[1])
        if aux[1] == aux[2]:
          print('cheguei aq')
        context.append(aux)

print(f"Tem-se um total de {len(context)} pares de palavras alvo e palavras contextuais")
# Out:
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# wanna  -->  feeling
# katniss  -->  rather
# the  -->  rotten
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# despite  -->  im
# today  -->  rather
# baba  -->  rotten
# i  -->  so
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# have  -->  im
# i  -->  feeling
# did  -->  rotten
# position  -->  so
# but  -->  im
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# separate  -->  im
# of  -->  feeling
# walrus  -->  rather
# purples  -->  so
# vain  -->  im
# what  -->  not
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# rich  -->  im
# updating  -->  feeling
# find  -->  rather
# probably  -->  rotten
# in  -->  im
# again  -->  not
# to  -->  very
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# have  -->  feeling
# the  -->  rather
# despite  -->  rotten
# under  -->  so
# don  -->  not
# need  -->  very
# my  -->  ambitious
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# a  -->  rather
# explain  -->  rotten
# the  -->  so
# menstrual  -->  im
# other  -->  very
# i  -->  ambitious
# virginia  -->  right
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# dont  -->  rotten
# into  -->  so
# sails  -->  im
# pre  -->  not
# to  -->  ambitious
# immature  -->  right
# i  -->  now
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# because  -->  so
# feel  -->  im
# feeling  -->  not
# separate  -->  very
# knew  -->  right
# my  -->  now
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# not  -->  im
# my  -->  not
# ways  -->  very
# yellow  -->  ambitious
# updating  -->  now
# ['im', 'feeling', 'rather', 'rotten', 'so', 'im', 'not', 'very', 'ambitious', 'right', 'now']
# boy  -->  not
# baba  -->  very
# our  -->  ambitious
# hide  -->  right
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# breathless  -->  updating
# the  -->  my
# i  -->  blog
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# so  -->  im
# at  -->  my
# want  -->  blog
# her  -->  because
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# explain  -->  im
# pre  -->  updating
# pre  -->  blog
# optimistic  -->  because
# let  -->  i
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# today  -->  im
# to  -->  updating
# when  -->  my
# to  -->  because
# vain  -->  i
# invaded  -->  feel
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# tear  -->  im
# on  -->  updating
# about  -->  my
# make  -->  blog
# don  -->  i
# my  -->  feel
# feel  -->  shitty
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# i  -->  updating
# n  -->  my
# will  -->  blog
# excitement  -->  because
# about  -->  feel
# been  -->  shitty
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# just  -->  my
# because  -->  blog
# don  -->  because
# role  -->  i
# feeling  -->  shitty
# ['im', 'updating', 'my', 'blog', 'because', 'i', 'feel', 'shitty']
# why  -->  blog
# under  -->  because
# of  -->  i
# i  -->  feel
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# i  -->  never
# be  -->  make
# are  -->  her
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# breathless  -->  i
# many  -->  make
# on  -->  her
# our  -->  separate
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# have  -->  i
# into  -->  never
# dont  -->  her
# extremely  -->  separate
# into  -->  from
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# in  -->  i
# a  -->  never
# t  -->  make
# helpless  -->  separate
# but  -->  from
# optimistic  -->  me
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# im  -->  i
# attention  -->  never
# more  -->  make
# the  -->  her
# i  -->  from
# to  -->  me
# purples  -->  because
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# so  -->  never
# im  -->  make
# make  -->  her
# only  -->  separate
# then  -->  me
# updating  -->  because
# the  -->  i
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# women  -->  make
# end  -->  her
# to  -->  separate
# that  -->  from
# be  -->  because
# was  -->  i
# ever  -->  don
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# never  -->  her
# im  -->  separate
# probably  -->  from
# rotten  -->  me
# have  -->  i
# vain  -->  don
# feeling  -->  t
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# would  -->  separate
# but  -->  from
# reader  -->  me
# and  -->  because
# my  -->  don
# i  -->  t
# it  -->  ever
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# i  -->  from
# extremely  -->  me
# feeling  -->  because
# feeling  -->  i
# knew  -->  t
# a  -->  ever
# emotional  -->  want
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# her  -->  me
# only  -->  because
# make  -->  i
# and  -->  don
# university  -->  ever
# extremely  -->  want
# as  -->  her
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# explain  -->  because
# uncommitted  -->  i
# my  -->  don
# left  -->  t
# happen  -->  want
# even  -->  her
# cant  -->  to
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# separate  -->  i
# n  -->  don
# because  -->  t
# uncommitted  -->  ever
# been  -->  her
# of  -->  to
# walrus  -->  feel
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# u  -->  don
# extremely  -->  t
# arrived  -->  ever
# a  -->  want
# people  -->  to
# this  -->  feel
# m  -->  like
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# a  -->  t
# next  -->  ever
# menstrual  -->  want
# for  -->  her
# a  -->  feel
# at  -->  like
# its  -->  i
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# week  -->  ever
# masters  -->  want
# for  -->  her
# about  -->  to
# i  -->  like
# tired  -->  i
# i  -->  m
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# pessimism  -->  want
# immature  -->  her
# was  -->  to
# a  -->  feel
# ever  -->  i
# boy  -->  m
# t  -->  ashamed
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# our  -->  her
# summer  -->  to
# the  -->  feel
# just  -->  like
# discontent  -->  m
# we  -->  ashamed
# i  -->  with
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# i  -->  to
# uncommitted  -->  feel
# a  -->  like
# despite  -->  i
# despite  -->  ashamed
# of  -->  with
# extremely  -->  her
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# same  -->  feel
# even  -->  like
# of  -->  i
# i  -->  m
# to  -->  with
# sure  -->  her
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# and  -->  like
# women  -->  i
# your  -->  m
# despite  -->  ashamed
# just  -->  her
# ['i', 'never', 'make', 'her', 'separate', 'from', 'me', 'because', 'i', 'don', 't', 'ever', 'want', 'her', 'to', 'feel', 'like', 'i', 'm', 'ashamed', 'with', 'her']
# the  -->  i
# mellow  -->  m
# m  -->  ashamed
# when  -->  with
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# clung  -->  left
# discontent  -->  with
# what  -->  my
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# fit  -->  i
# one  -->  with
# mad  -->  my
# relationship  -->  bouquet
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# now  -->  i
# emotional  -->  left
# when  -->  my
# vain  -->  bouquet
# not  -->  of
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# of  -->  i
# the  -->  left
# feel  -->  with
# her  -->  bouquet
# are  -->  of
# feel  -->  red
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# feeling  -->  i
# a  -->  left
# where  -->  with
# my  -->  my
# cheguei aq
# tired  -->  of
# in  -->  red
# feeling  -->  and
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# slightly  -->  left
# i  -->  with
# what  -->  my
# virginia  -->  bouquet
# of  -->  red
# to  -->  and
# when  -->  yellow
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# im  -->  with
# uncomfortable  -->  my
# were  -->  bouquet
# it  -->  of
# anger  -->  and
# i  -->  yellow
# telephone  -->  tulips
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# which  -->  my
# baba  -->  bouquet
# her  -->  of
# ways  -->  red
# uncomfortable  -->  yellow
# i  -->  tulips
# feeling  -->  under
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# to  -->  bouquet
# her  -->  of
# uncommitted  -->  red
# walk  -->  and
# again  -->  tulips
# tulips  -->  under
# anger  -->  my
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# and  -->  of
# i  -->  red
# make  -->  and
# because  -->  yellow
# should  -->  under
# as  -->  my
# just  -->  arm
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# i  -->  red
# have  -->  and
# now  -->  yellow
# my  -->  tulips
# let  -->  my
# im  -->  arm
# was  -->  feeling
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# that  -->  and
# sure  -->  yellow
# was  -->  tulips
# knows  -->  under
# knows  -->  arm
# kind  -->  feeling
# grumpy  -->  slightly
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# despite  -->  yellow
# im  -->  tulips
# jest  -->  under
# and  -->  my
# i  -->  feeling
# i  -->  slightly
# as  -->  more
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# virginia  -->  tulips
# publicity  -->  under
# left  -->  my
# find  -->  arm
# happen  -->  slightly
# feel  -->  more
# will  -->  optimistic
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# world  -->  under
# same  -->  my
# again  -->  arm
# reds  -->  feeling
# like  -->  more
# in  -->  optimistic
# at  -->  than
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# i  -->  my
# grumpy  -->  arm
# i  -->  feeling
# summer  -->  slightly
# odd  -->  optimistic
# more  -->  than
# people  -->  when
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# was  -->  arm
# on  -->  feeling
# for  -->  slightly
# feel  -->  more
# do  -->  than
# t  -->  when
# being  -->  i
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# feel  -->  feeling
# me  -->  slightly
# so  -->  more
# im  -->  optimistic
# menstrual  -->  when
# as  -->  i
# just  -->  arrived
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# because  -->  slightly
# at  -->  more
# telephone  -->  optimistic
# immature  -->  than
# will  -->  i
# in  -->  arrived
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# rather  -->  more
# see  -->  optimistic
# im  -->  than
# like  -->  when
# have  -->  arrived
# ['i', 'left', 'with', 'my', 'bouquet', 'of', 'red', 'and', 'yellow', 'tulips', 'under', 'my', 'arm', 'feeling', 'slightly', 'more', 'optimistic', 'than', 'when', 'i', 'arrived']
# cant  -->  optimistic
# when  -->  than
# whom  -->  when
# today  -->  i
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# katniss  -->  was
# am  -->  feeling
# world  -->  a
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# uncommitted  -->  i
# t  -->  feeling
# knew  -->  a
# and  -->  little
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# sure  -->  i
# am  -->  was
# i  -->  a
# today  -->  little
# happen  -->  vain
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# her  -->  i
# cant  -->  was
# today  -->  feeling
# many  -->  little
# do  -->  vain
# did  -->  when
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# were  -->  i
# the  -->  was
# so  -->  feeling
# particularly  -->  a
# immature  -->  vain
# happen  -->  when
# as  -->  i
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# call  -->  was
# sails  -->  feeling
# i  -->  a
# what  -->  little
# vain  -->  when
# menstrual  -->  i
# make  -->  did
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# her  -->  feeling
# where  -->  a
# holding  -->  little
# the  -->  vain
# anywhere  -->  i
# heartbroken  -->  did
# the  -->  this
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# one  -->  a
# emotional  -->  little
# fight  -->  vain
# fit  -->  when
# for  -->  did
# don  -->  this
# with  -->  one
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# fight  -->  little
# was  -->  vain
# don  -->  when
# was  -->  i
# of  -->  this
# relationship  -->  one
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# not  -->  vain
# perfect  -->  when
# as  -->  i
# breathless  -->  did
# purples  -->  one
# ['i', 'was', 'feeling', 'a', 'little', 'vain', 'when', 'i', 'did', 'this', 'one']
# jest  -->  when
# with  -->  i
# happen  -->  did
# program  -->  this
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# fight  -->  cant
# a  -->  walk
# breathless  -->  into
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# again  -->  i
# even  -->  walk
# her  -->  into
# but  -->  a
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# the  -->  i
# summer  -->  cant
# i  -->  into
# was  -->  a
# than  -->  shop
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# again  -->  i
# from  -->  cant
# discontent  -->  walk
# separate  -->  a
# have  -->  shop
# women  -->  anywhere
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# holding  -->  i
# hide  -->  cant
# to  -->  walk
# i  -->  into
# beautifully  -->  shop
# for  -->  anywhere
# we  -->  where
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# was  -->  cant
# whom  -->  walk
# arrived  -->  into
# that  -->  a
# my  -->  anywhere
# get  -->  where
# n  -->  i
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# t  -->  walk
# im  -->  into
# when  -->  a
# holding  -->  shop
# u  -->  where
# each  -->  i
# about  -->  do
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# n  -->  into
# need  -->  a
# of  -->  shop
# despite  -->  anywhere
# was  -->  i
# shitty  -->  do
# masters  -->  not
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# program  -->  a
# vain  -->  shop
# but  -->  anywhere
# week  -->  where
# shitty  -->  do
# supportive  -->  not
# where  -->  feel
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# your  -->  shop
# these  -->  anywhere
# at  -->  where
# tear  -->  i
# i  -->  not
# than  -->  feel
# feel  -->  uncomfortable
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# uncommitted  -->  anywhere
# program  -->  where
# mellow  -->  i
# jest  -->  do
# need  -->  feel
# just  -->  uncomfortable
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# red  -->  where
# and  -->  i
# i  -->  do
# updating  -->  not
# a  -->  uncomfortable
# ['i', 'cant', 'walk', 'into', 'a', 'shop', 'anywhere', 'where', 'i', 'do', 'not', 'feel', 'uncomfortable']
# being  -->  i
# was  -->  do
# heartbroken  -->  not
# do  -->  feel
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# beautifully  -->  felt
# im  -->  anger
# role  -->  when
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# feel  -->  i
# walrus  -->  anger
# knowing  -->  when
# same  -->  at
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# fight  -->  i
# journey  -->  felt
# feeling  -->  when
# when  -->  at
# walk  -->  the
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# journey  -->  i
# publicity  -->  felt
# in  -->  anger
# feeling  -->  at
# vain  -->  the
# i  -->  end
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# helpless  -->  i
# that  -->  felt
# uncomfortable  -->  anger
# clung  -->  when
# other  -->  the
# as  -->  end
# perfect  -->  of
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# let  -->  felt
# that  -->  anger
# menstrual  -->  when
# wanna  -->  at
# of  -->  end
# wanna  -->  of
# now  -->  a
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# so  -->  anger
# even  -->  when
# because  -->  at
# rotten  -->  the
# with  -->  of
# been  -->  a
# knew  -->  telephone
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# position  -->  when
# even  -->  at
# position  -->  the
# than  -->  end
# my  -->  a
# than  -->  telephone
# only  -->  call
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# these  -->  at
# arm  -->  the
# it  -->  end
# world  -->  of
# rotten  -->  telephone
# blog  -->  call
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# attention  -->  the
# the  -->  end
# i  -->  of
# getting  -->  a
# i  -->  call
# ['i', 'felt', 'anger', 'when', 'at', 'the', 'end', 'of', 'a', 'telephone', 'call']
# what  -->  end
# little  -->  of
# felt  -->  a
# happen  -->  telephone
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# yellow  -->  explain
# optimistic  -->  why
# let  -->  i
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# week  -->  i
# agitated  -->  why
# under  -->  i
# m  -->  clung
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# the  -->  i
# tired  -->  explain
# kind  -->  i
# myself  -->  clung
# telephone  -->  to
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# i  -->  i
# cheguei aq
# each  -->  explain
# then  -->  why
# just  -->  clung
# been  -->  to
# with  -->  a
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# feeling  -->  i
# of  -->  explain
# should  -->  why
# baba  -->  i
# and  -->  to
# holding  -->  a
# a  -->  relationship
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# find  -->  explain
# are  -->  why
# tired  -->  i
# knows  -->  clung
# which  -->  a
# my  -->  relationship
# get  -->  with
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# this  -->  why
# where  -->  i
# as  -->  clung
# her  -->  to
# to  -->  relationship
# our  -->  with
# knows  -->  a
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# reader  -->  i
# clung  -->  clung
# cheguei aq
# in  -->  to
# the  -->  a
# and  -->  with
# im  -->  a
# knowing  -->  boy
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# not  -->  clung
# pay  -->  to
# feeling  -->  a
# next  -->  relationship
# these  -->  a
# uncomfortable  -->  boy
# the  -->  who
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# comfortable  -->  to
# your  -->  a
# who  -->  relationship
# so  -->  with
# the  -->  boy
# explain  -->  who
# a  -->  was
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# her  -->  a
# publicity  -->  relationship
# accepted  -->  with
# been  -->  a
# were  -->  who
# myself  -->  was
# helpless  -->  in
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# helpless  -->  relationship
# see  -->  with
# who  -->  a
# group  -->  boy
# are  -->  was
# bcoz  -->  in
# on  -->  many
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# ways  -->  with
# have  -->  a
# feel  -->  boy
# comfortable  -->  who
# who  -->  in
# of  -->  many
# i  -->  ways
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# explain  -->  a
# i  -->  boy
# invaded  -->  who
# my  -->  was
# me  -->  many
# eager  -->  ways
# the  -->  immature
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# which  -->  boy
# at  -->  who
# feeling  -->  was
# want  -->  in
# not  -->  ways
# explain  -->  immature
# happen  -->  and
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# very  -->  who
# i  -->  was
# sails  -->  in
# her  -->  many
# blog  -->  immature
# grumpy  -->  and
# have  -->  uncommitted
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# kind  -->  was
# blog  -->  in
# feeling  -->  many
# and  -->  ways
# was  -->  and
# felt  -->  uncommitted
# accepted  -->  despite
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# i  -->  in
# eager  -->  many
# walrus  -->  ways
# each  -->  immature
# under  -->  uncommitted
# katniss  -->  despite
# invaded  -->  the
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# getting  -->  many
# not  -->  ways
# not  -->  immature
# probably  -->  and
# anger  -->  despite
# sure  -->  the
# little  -->  excitement
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# role  -->  ways
# discontent  -->  immature
# telephone  -->  and
# feel  -->  uncommitted
# i  -->  the
# the  -->  excitement
# ever  -->  i
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# feeling  -->  immature
# yellow  -->  and
# i  -->  uncommitted
# only  -->  despite
# hide  -->  excitement
# to  -->  i
# despite  -->  should
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# happen  -->  and
# uncommitted  -->  uncommitted
# cheguei aq
# was  -->  despite
# wanna  -->  the
# the  -->  i
# t  -->  should
# pay  -->  have
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# me  -->  uncommitted
# feel  -->  despite
# now  -->  the
# a  -->  excitement
# i  -->  should
# being  -->  have
# other  -->  been
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# explain  -->  despite
# i  -->  the
# program  -->  excitement
# been  -->  i
# about  -->  have
# same  -->  been
# i  -->  feeling
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# on  -->  the
# my  -->  excitement
# like  -->  i
# a  -->  should
# jest  -->  been
# wanna  -->  feeling
# handful  -->  for
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# feel  -->  excitement
# on  -->  i
# a  -->  should
# arrived  -->  have
# anywhere  -->  feeling
# my  -->  for
# the  -->  getting
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# little  -->  i
# university  -->  should
# immature  -->  have
# so  -->  been
# t  -->  for
# its  -->  getting
# do  -->  accepted
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# a  -->  should
# role  -->  have
# other  -->  been
# my  -->  feeling
# same  -->  getting
# feeling  -->  accepted
# am  -->  into
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# ashamed  -->  have
# virginia  -->  been
# i  -->  feeling
# when  -->  for
# sure  -->  accepted
# vain  -->  into
# did  -->  the
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# it  -->  been
# m  -->  feeling
# clung  -->  for
# the  -->  getting
# each  -->  into
# each  -->  the
# red  -->  masters
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# week  -->  feeling
# kind  -->  for
# breathless  -->  getting
# pessimism  -->  accepted
# discontent  -->  the
# not  -->  masters
# now  -->  program
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# reader  -->  for
# with  -->  getting
# as  -->  accepted
# heartbroken  -->  into
# was  -->  masters
# from  -->  program
# felt  -->  at
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# a  -->  getting
# our  -->  accepted
# emotional  -->  into
# the  -->  the
# cheguei aq
# walrus  -->  program
# odd  -->  at
# me  -->  the
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# ever  -->  accepted
# vacation  -->  into
# a  -->  the
# with  -->  masters
# mad  -->  at
# that  -->  the
# did  -->  university
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# program  -->  into
# felt  -->  the
# next  -->  masters
# the  -->  program
# feel  -->  the
# breathless  -->  university
# than  -->  of
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# discontent  -->  the
# feel  -->  masters
# so  -->  program
# heartbroken  -->  at
# i  -->  university
# red  -->  of
# publicity  -->  virginia
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# a  -->  masters
# a  -->  program
# as  -->  at
# very  -->  the
# with  -->  of
# i  -->  virginia
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# eager  -->  program
# never  -->  at
# with  -->  the
# just  -->  university
# u  -->  virginia
# ['i', 'explain', 'why', 'i', 'clung', 'to', 'a', 'relationship', 'with', 'a', 'boy', 'who', 'was', 'in', 'many', 'ways', 'immature', 'and', 'uncommitted', 'despite', 'the', 'excitement', 'i', 'should', 'have', 'been', 'feeling', 'for', 'getting', 'accepted', 'into', 'the', 'masters', 'program', 'at', 'the', 'university', 'of', 'virginia']
# walrus  -->  at
# when  -->  the
# women  -->  university
# im  -->  of
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# i  -->  like
# wanna  -->  to
# what  -->  have
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# to  -->  i
# again  -->  to
# call  -->  have
# rich  -->  the
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# blog  -->  i
# position  -->  like
# mellow  -->  have
# my  -->  the
# position  -->  same
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# a  -->  i
# myself  -->  like
# your  -->  to
# again  -->  the
# explain  -->  same
# do  -->  breathless
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# hide  -->  i
# as  -->  like
# very  -->  to
# feeling  -->  have
# happen  -->  same
# i  -->  breathless
# accepted  -->  feeling
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# katniss  -->  like
# wanna  -->  to
# handful  -->  have
# anger  -->  the
# mellow  -->  breathless
# to  -->  feeling
# women  -->  as
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# i  -->  to
# reader  -->  have
# will  -->  the
# this  -->  same
# and  -->  feeling
# did  -->  as
# same  -->  a
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# getting  -->  have
# m  -->  the
# knowing  -->  same
# eager  -->  breathless
# our  -->  as
# vacation  -->  a
# each  -->  reader
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# feel  -->  the
# dont  -->  same
# don  -->  breathless
# ashamed  -->  feeling
# my  -->  a
# of  -->  reader
# than  -->  eager
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# rotten  -->  same
# knowing  -->  breathless
# even  -->  feeling
# are  -->  as
# to  -->  reader
# than  -->  eager
# comfortable  -->  to
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# only  -->  breathless
# need  -->  feeling
# on  -->  as
# felt  -->  a
# excitement  -->  eager
# my  -->  to
# see  -->  see
# cheguei aq
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# agitated  -->  feeling
# just  -->  as
# not  -->  a
# cant  -->  reader
# one  -->  to
# many  -->  see
# vain  -->  what
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# the  -->  as
# supportive  -->  a
# supportive  -->  reader
# explain  -->  eager
# baba  -->  see
# katniss  -->  what
# see  -->  will
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# was  -->  a
# little  -->  reader
# when  -->  eager
# probably  -->  to
# yellow  -->  what
# for  -->  will
# just  -->  happen
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# because  -->  reader
# just  -->  eager
# i  -->  to
# my  -->  see
# myself  -->  will
# my  -->  happen
# ashamed  -->  next
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# wanna  -->  eager
# a  -->  to
# extremely  -->  see
# the  -->  what
# many  -->  happen
# rich  -->  next
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# i  -->  to
# never  -->  see
# from  -->  what
# ways  -->  will
# my  -->  next
# ['i', 'like', 'to', 'have', 'the', 'same', 'breathless', 'feeling', 'as', 'a', 'reader', 'eager', 'to', 'see', 'what', 'will', 'happen', 'next']
# anywhere  -->  see
# extremely  -->  what
# extremely  -->  will
# kind  -->  happen
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# of  -->  jest
# supportive  -->  i
# i  -->  feel
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# dont  -->  i
# deepens  -->  i
# vain  -->  feel
# with  -->  grumpy
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# as  -->  i
# for  -->  jest
# the  -->  feel
# and  -->  grumpy
# heartbroken  -->  tired
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# t  -->  i
# yellow  -->  jest
# today  -->  i
# university  -->  grumpy
# of  -->  tired
# separate  -->  and
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# a  -->  i
# other  -->  jest
# world  -->  i
# one  -->  feel
# i  -->  tired
# knew  -->  and
# and  -->  pre
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# tulips  -->  jest
# i  -->  i
# cheguei aq
# optimistic  -->  feel
# arrived  -->  grumpy
# explain  -->  and
# what  -->  pre
# with  -->  menstrual
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# supportive  -->  i
# i  -->  feel
# your  -->  grumpy
# been  -->  tired
# these  -->  pre
# was  -->  menstrual
# even  -->  which
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# helpless  -->  feel
# cant  -->  grumpy
# to  -->  tired
# i  -->  and
# are  -->  menstrual
# knew  -->  which
# tear  -->  i
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# attention  -->  grumpy
# uncommitted  -->  tired
# i  -->  and
# tulips  -->  pre
# was  -->  which
# feeling  -->  i
# of  -->  probably
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# for  -->  tired
# today  -->  and
# virginia  -->  pre
# other  -->  menstrual
# im  -->  i
# i  -->  probably
# to  -->  am
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# emotional  -->  and
# wanna  -->  pre
# call  -->  menstrual
# anywhere  -->  which
# invaded  -->  probably
# that  -->  am
# into  -->  but
# ['i', 'jest', 'i', 'feel', 'grumpy', 'tired', 'and', 'pre', 'menstrual', 'which', 'i', 'probably', 'am', 'but', 'then', 'again', 'its', 'only', 'been', 'a', 'week', 'and', 'im', 'about', 'as', 'fit', 'as', 'a', 'walrus', 'on', 'vacation', 'for', 'the', 'summer']
# we  -->  pre
# because  -->  menstrual
# rather  -->  which
# make  -->  i
# heartbroken  -->  am
# happen  -->  but
# n  -->  then
# ...
# cant  -->  heartbroken
# sails  -->  as
# emotional  -->  im
# helpless  -->  sure
# for  -->  was
# ['i', 'was', 'feeling', 'as', 'heartbroken', 'as', 'im', 'sure', 'katniss', 'was']
# call  -->  as
# of  -->  im
# many  -->  sure
# t  -->  katniss
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# shitty  -->  feel
# i  -->  a
# tear  -->  little
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# a  -->  i
# did  -->  a
# her  -->  little
# tear  -->  mellow
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# i  -->  i
# cheguei aq
# of  -->  feel
# and  -->  little
# and  -->  mellow
# we  -->  today
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# optimistic  -->  i
# supportive  -->  feel
# about  -->  a
# grumpy  -->  mellow
# role  -->  today
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# katniss  -->  i
# was  -->  feel
# week  -->  a
# comfortable  -->  little
# im  -->  today
# ['i', 'feel', 'a', 'little', 'mellow', 'today']
# t  -->  feel
# like  -->  a
# bouquet  -->  little
# breathless  -->  mellow
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# one  -->  feel
# a  -->  like
# now  -->  my
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# yellow  -->  i
# hide  -->  like
# optimistic  -->  my
# updating  -->  only
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# me  -->  i
# ways  -->  feel
# my  -->  my
# cheguei aq
# i  -->  only
# be  -->  role
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# i  -->  i
# cheguei aq
# because  -->  feel
# invaded  -->  like
# now  -->  only
# role  -->  role
# cheguei aq
# just  -->  now
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# t  -->  i
# role  -->  feel
# knowing  -->  like
# the  -->  my
# explain  -->  role
# dont  -->  now
# who  -->  would
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# on  -->  feel
# it  -->  like
# i  -->  my
# felt  -->  only
# feeling  -->  now
# the  -->  would
# because  -->  be
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# have  -->  like
# the  -->  my
# i  -->  only
# baba  -->  role
# our  -->  would
# knows  -->  be
# clung  -->  to
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# immature  -->  my
# program  -->  only
# m  -->  role
# feeling  -->  now
# that  -->  be
# myself  -->  to
# a  -->  tear
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# arm  -->  only
# slightly  -->  role
# more  -->  now
# and  -->  would
# should  -->  to
# mad  -->  tear
# in  -->  your
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# particularly  -->  role
# publicity  -->  now
# like  -->  would
# myself  -->  be
# a  -->  tear
# a  -->  your
# explain  -->  sails
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# arm  -->  now
# mellow  -->  would
# mad  -->  be
# a  -->  to
# katniss  -->  your
# with  -->  sails
# relationship  -->  with
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# comfortable  -->  would
# eager  -->  be
# i  -->  to
# handful  -->  tear
# and  -->  sails
# the  -->  with
# accepted  -->  my
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# n  -->  be
# the  -->  to
# a  -->  tear
# we  -->  your
# our  -->  with
# felt  -->  my
# should  -->  pessimism
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# comfortable  -->  to
# but  -->  tear
# find  -->  your
# breathless  -->  sails
# next  -->  my
# been  -->  pessimism
# never  -->  and
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# call  -->  tear
# where  -->  your
# of  -->  sails
# ever  -->  with
# make  -->  pessimism
# rather  -->  and
# feeling  -->  discontent
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# summer  -->  your
# im  -->  sails
# don  -->  with
# why  -->  my
# get  -->  and
# feel  -->  discontent
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# feeling  -->  sails
# separate  -->  with
# mad  -->  my
# comfortable  -->  pessimism
# i  -->  discontent
# ['i', 'feel', 'like', 'my', 'only', 'role', 'now', 'would', 'be', 'to', 'tear', 'your', 'sails', 'with', 'my', 'pessimism', 'and', 'discontent']
# im  -->  with
# and  -->  my
# arrived  -->  pessimism
# that  -->  and
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# getting  -->  feel
# feeling  -->  just
# emotional  -->  bcoz
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# when  -->  i
# we  -->  just
# rich  -->  bcoz
# at  -->  a
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# walk  -->  i
# of  -->  feel
# anywhere  -->  bcoz
# ever  -->  a
# on  -->  fight
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# been  -->  i
# been  -->  feel
# position  -->  just
# kind  -->  a
# women  -->  fight
# when  -->  we
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# bouquet  -->  i
# a  -->  feel
# group  -->  just
# vacation  -->  bcoz
# pre  -->  fight
# that  -->  we
# heartbroken  -->  get
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# feeling  -->  feel
# my  -->  just
# don  -->  bcoz
# fight  -->  a
# a  -->  we
# holding  -->  get
# each  -->  mad
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# the  -->  just
# right  -->  bcoz
# yellow  -->  a
# feeling  -->  fight
# end  -->  get
# summer  -->  mad
# feel  -->  to
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# me  -->  bcoz
# summer  -->  a
# tear  -->  fight
# im  -->  we
# ever  -->  mad
# been  -->  to
# not  -->  each
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# my  -->  a
# i  -->  fight
# of  -->  we
# a  -->  get
# i  -->  to
# odd  -->  each
# right  -->  other
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# my  -->  fight
# now  -->  we
# what  -->  get
# whom  -->  mad
# to  -->  each
# pay  -->  other
# particularly  -->  n
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# sails  -->  we
# of  -->  get
# agitated  -->  mad
# rather  -->  to
# same  -->  other
# each  -->  n
# and  -->  u
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# pay  -->  get
# ever  -->  mad
# pre  -->  to
# when  -->  each
# immature  -->  n
# of  -->  u
# on  -->  wanna
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# attention  -->  mad
# knew  -->  to
# felt  -->  each
# t  -->  other
# than  -->  u
# feel  -->  wanna
# blog  -->  make
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# fit  -->  to
# a  -->  each
# and  -->  other
# now  -->  n
# role  -->  wanna
# a  -->  make
# for  -->  a
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# just  -->  each
# t  -->  other
# pessimism  -->  n
# extremely  -->  u
# the  -->  make
# will  -->  a
# red  -->  publicity
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# for  -->  other
# myself  -->  n
# helpless  -->  u
# pay  -->  wanna
# feeling  -->  a
# so  -->  publicity
# one  -->  n
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# yellow  -->  n
# when  -->  u
# feel  -->  wanna
# end  -->  make
# university  -->  publicity
# u  -->  n
# were  -->  let
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# rich  -->  u
# bcoz  -->  wanna
# a  -->  make
# a  -->  a
# cheguei aq
# ambitious  -->  n
# discontent  -->  let
# heartbroken  -->  the
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# and  -->  wanna
# was  -->  make
# feeling  -->  a
# anywhere  -->  publicity
# end  -->  let
# on  -->  the
# me  -->  world
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# feel  -->  make
# anywhere  -->  a
# i  -->  publicity
# helpless  -->  n
# cant  -->  the
# group  -->  world
# t  -->  knows
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# anywhere  -->  a
# probably  -->  publicity
# helpless  -->  n
# one  -->  let
# end  -->  world
# today  -->  knows
# handful  -->  about
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# so  -->  publicity
# discontent  -->  n
# its  -->  let
# im  -->  the
# discontent  -->  knows
# as  -->  about
# who  -->  our
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# feeling  -->  n
# reader  -->  let
# publicity  -->  the
# updating  -->  world
# then  -->  about
# clung  -->  our
# arm  -->  fight
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# role  -->  let
# even  -->  the
# do  -->  world
# the  -->  knows
# who  -->  our
# need  -->  fight
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# my  -->  the
# bcoz  -->  world
# a  -->  knows
# like  -->  about
# i  -->  fight
# ['i', 'feel', 'just', 'bcoz', 'a', 'fight', 'we', 'get', 'mad', 'to', 'each', 'other', 'n', 'u', 'wanna', 'make', 'a', 'publicity', 'n', 'let', 'the', 'world', 'knows', 'about', 'our', 'fight']
# just  -->  world
# im  -->  knows
# yellow  -->  about
# and  -->  our
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# invaded  -->  feel
# group  -->  like
# t  -->  reds
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# which  -->  i
# felt  -->  like
# publicity  -->  reds
# wanna  -->  and
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# with  -->  i
# boy  -->  feel
# happen  -->  reds
# handful  -->  and
# reader  -->  purples
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# to  -->  i
# have  -->  feel
# same  -->  like
# felt  -->  and
# arrived  -->  purples
# walrus  -->  are
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# arrived  -->  i
# on  -->  feel
# summer  -->  like
# make  -->  reds
# deepens  -->  purples
# make  -->  are
# which  -->  just
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# vacation  -->  feel
# im  -->  like
# world  -->  reds
# were  -->  and
# when  -->  are
# this  -->  just
# of  -->  so
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# excitement  -->  like
# of  -->  reds
# red  -->  and
# our  -->  purples
# i  -->  just
# i  -->  so
# and  -->  rich
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# only  -->  reds
# am  -->  and
# to  -->  purples
# but  -->  are
# im  -->  so
# this  -->  rich
# odd  -->  and
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# feel  -->  and
# rich  -->  purples
# probably  -->  are
# into  -->  just
# i  -->  rich
# summer  -->  and
# walk  -->  kind
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# because  -->  purples
# next  -->  are
# helpless  -->  just
# it  -->  so
# feel  -->  and
# purples  -->  kind
# the  -->  of
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# let  -->  are
# discontent  -->  just
# im  -->  so
# menstrual  -->  rich
# i  -->  kind
# let  -->  of
# holding  -->  perfect
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# fit  -->  just
# tulips  -->  so
# heartbroken  -->  rich
# i  -->  and
# feel  -->  of
# many  -->  perfect
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# im  -->  so
# separate  -->  rich
# with  -->  and
# should  -->  kind
# i  -->  perfect
# ['i', 'feel', 'like', 'reds', 'and', 'purples', 'are', 'just', 'so', 'rich', 'and', 'kind', 'of', 'perfect']
# left  -->  rich
# optimistic  -->  and
# i  -->  kind
# this  -->  of
# Tem-se um total de 2018 pares de palavras alvo e palavras contextuais

# %%
while True:
  losses = []
  context_batches = get_batches(word_to_index, negative= True, context= context, batch_size=1000)
  for i in range(len(context_batches)):
    w2v.zero_grad()
    target_tensor, meaning_tensor, negative_tensor = context_batches[i]
    loss = w2v(target_tensor, meaning_tensor, negative_tensor)
    loss.backward()
    optimizer.step()
    losses.append(loss.data)
  print("loss: ", np.mean(losses))
  early_stopping.update_loss(np.mean(losses))
  if early_stopping.stop_training():
    break
# Out:
# loss:  7592.9995
# loss:  7446.691
# Ganho de custo: 759201.86
# loss:  7322.768
# Ganho de custo: 759203.52
# loss:  7204.01
# Ganho de custo: 759205.08
# loss:  7088.2026
# Ganho de custo: 759206.59
# loss:  6975.56

# ----> <a href='vscode-notebook-cell:/c%3A/Users/davif/OneDrive/Documentos/GitHub/LIBRA/colabs/teste.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a>   optimizer.step()
#      <a href='vscode-notebook-cell:/c%3A/Users/davif/OneDrive/Documentos/GitHub/LIBRA/colabs/teste.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a>   losses.append(loss.data)
#      <a href='vscode-notebook-cell:/c%3A/Users/davif/OneDrive/Documentos/GitHub/LIBRA/colabs/teste.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a> print("loss: ", np.mean(losses))
#
# File c:\Users\davif\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File c:\Users\davif\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File c:\Users\davif\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\adam.py:163, in Adam.step(self, closure)
#     152     beta1, beta2 = group['betas']
#     154     self._init_group(
#     155         group,
#     156         params_with_grad,
#    (...)
#     160         max_exp_avg_sqs,
#     161         state_steps)
# --> 163     adam(
#     164         params_with_grad,
#     165         grads,
#     166         exp_avgs,
#     167         exp_avg_sqs,
#     168         max_exp_avg_sqs,
#     169         state_steps,
#     170         amsgrad=group['amsgrad'],
#     171         beta1=beta1,
#     172         beta2=beta2,
#     173         lr=group['lr'],
#     174         weight_decay=group['weight_decay'],
#     175         eps=group['eps'],
#     176         maximize=group['maximize'],
#     177         foreach=group['foreach'],
#     178         capturable=group['capturable'],
#     179         differentiable=group['differentiable'],
#     180         fused=group['fused'],
#     181         grad_scale=getattr(self, "grad_scale", None),
#     182         found_inf=getattr(self, "found_inf", None),
#     183     )
#     185 return loss
#
# File c:\Users\davif\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\adam.py:311, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     308 else:
#     309     func = _single_tensor_adam
# --> 311 func(params,
#     312      grads,
#     313      exp_avgs,
#     314      exp_avg_sqs,
#     315      max_exp_avg_sqs,
#     316      state_steps,
#     317      amsgrad=amsgrad,
#     318      beta1=beta1,
#     319      beta2=beta2,
#     320      lr=lr,
#     321      weight_decay=weight_decay,
#     322      eps=eps,
#     323      maximize=maximize,
#     324      capturable=capturable,
#     325      differentiable=differentiable,
#     326      grad_scale=grad_scale,
#     327      found_inf=found_inf)
#
# File c:\Users\davif\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\adam.py:385, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     383 # Decay the first and second moment running average coefficient
#     384 exp_avg.lerp_(grad, 1 - beta1)
# --> 385 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     387 if capturable or differentiable:
#     388     step = step_t
#
# KeyboardInterrupt:

# %% [markdown]
# não converge com o negativo
